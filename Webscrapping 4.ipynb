# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
#importing chromedriver
driver = webdriver.Chrome(r'C:\Users\SALMA\Downloads\chromedriver_win32\chromedriver.exe')

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(2) #wait for 2 m.s.

Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

for i in range(1,31): #We have 30 rows, running the loop from 1 to 31
    Rank_tags=driver.find_element_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr["+str(i)+"]/td[1]") #Rank
    Rank.append(Rank_tags.text) #Appending Rank
    Name_tags=driver.find_element_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr["+str(i)+"]/td[2]") #Name
    Name.append(Name_tags.text[1:-5]) #Taking only Song Name
    Artist_tags=driver.find_element_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr["+str(i)+"]/td[3]") #Artist
    Artist.append(Artist_tags.text) #Artist Name
    Views_tags=driver.find_element_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr["+str(i)+"]/td[4]") #Upload_date
    Views.append(Views_tags.text) #Number of views in billions
    Upload_date_tags=driver.find_element_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr["+str(i)+"]/td[5]") #Views
    Upload_date.append(Upload_date_tags.text) #Upload Date
    
Most_viewed_video=pd.DataFrame({}) #DataFrame
Most_viewed_video["RANK"]= Rank
Most_viewed_video["NAME"]= Name
Most_viewed_video["ARTIST"]= Artist
Most_viewed_video["UPLOAD DATE"]= Upload_date
Most_viewed_video["Views (billions)"]= Views
Most_viewed_video
# Out:
#    RANK                                       NAME  \
# 0    1.                            Baby Shark Danc
# 1    2.                                   Despacit
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.  Learning Colors – Colorful Eggs on a Farm
# 7    8.   Masha and the Bear – Recipe for Disaster
# 8    9.                Phonics Song with Two Words
# 9   10.                                Uptown Funk
# 10  11.                              Gangnam Style
# 11  12.                             Dame Tu Cosita
# 12  13.                          Wheels on the Bus
# 13  14.                                      Sugar
# 14  15.                                       Roar
# 15  16.                                      Sorry
# 16  17.                             Counting Stars
# 17  18.                          Thinking Out Loud
# 18  19.                             Girls Like You
# 19  20.                                     Axel F
# 20  21.                                      Faded
# 21  22.                                 Dark Horse
# 22  23.                                 Let Her Go
# 23  24.                                   Bailando
# 24  25.                                    Lean On
# 25  26.                               Shake It Off
# 26  27.                        Baa Baa Black Sheep
# 27  28.                                    Perfect
# 28  29.           Waka Waka (This Time for Africa)
# 29  30.                                   Mi Gente
#
#                                          ARTIST        UPLOAD DATE  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                    Luis Fonsi   January 12, 2017
# 2                                   LooLoo Kids    October 8, 2016
# 3                                    Ed Sheeran   January 30, 2017
# 4                                   Wiz Khalifa      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                   Miroshka TV  February 27, 2018
# 7                                    Get Movies   January 31, 2012
# 8                                     ChuChu TV      March 6, 2014
# 9                                   Mark Ronson  November 19, 2014
# 10                                          Psy      July 15, 2012
# 11                                    El Chombo      April 5, 2018
# 12                   Cocomelon – Nursery Rhymes       May 24, 2018
# 13                                     Maroon 5   January 14, 2015
# 14                                   Katy Perry  September 5, 2013
# 15                                Justin Bieber   October 22, 2015
# 16                                  OneRepublic       May 31, 2013
# 17                                   Ed Sheeran    October 7, 2014
# 18                                     Maroon 5       May 31, 2018
# 19                                   Crazy Frog      June 16, 2009
# 20                                  Alan Walker   December 3, 2015
# 21                                   Katy Perry  February 20, 2014
# 22                                    Passenger      July 25, 2012
# 23                             Enrique Iglesias     April 11, 2014
# 24                                  Major Lazer     March 22, 2015
# 25                                 Taylor Swift    August 18, 2014
# 26                   Cocomelon – Nursery Rhymes      June 25, 2018
# 27                                   Ed Sheeran   November 9, 2017
# 28                                      Shakira       June 4, 2010
# 29                                     J Balvin      June 29, 2017
#
#    Views (billions)
# 0             10.23
# 1              7.75
# 2              6.18
# 3              5.62
# 4              5.42
# 5              5.01
# 6              4.56
# 7              4.48
# 8              4.48
# 9              4.47
# 10             4.35
# 11             3.86
# 12             3.70
# 13             3.65
# 14             3.53
# 15             3.51
# 16             3.51
# 17             3.41
# 18             3.24
# 19             3.24
# 20             3.23
# 21             3.23
# 22             3.18
# 23             3.17
# 24             3.17
# 25             3.15
# 26             3.14
# 27             3.10
# 28             3.06
# 29             3.04

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
url = 'https://www.bcci.tv/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

fixtures=driver.find_element_by_xpath("//div[@class='collapse navbar-collapse']/ul/li[2]/a") #Locating to International Fixtures
driver.get(fixtures.get_attribute('href')) #Opening International Fixtuers page
time.sleep(4) #wait for 2 m.s.

Match_title = []
Series = []
Place = []
Date = []
Time = []

title=driver.find_elements_by_xpath("//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']/div/div[1]/h5[2]/span") #Title of the Seriers
for i in title:
    Series.append(i.text)
    
name=driver.find_elements_by_xpath("//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']/div/div[1]/h5[2]/span") #Match Title
for i in name:
    Match_title.append(i.text)

    
loc=driver.find_elements_by_xpath("//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']/div/div[4]/div") #Location
for i in loc:
    Place.append(i.text)

    
#t2=driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[1]") #Month
#dat = len(dt1)
#for i in range(0,dat):
#    Date.append(dt1[i].text+" "+dt2[i].text) #adding Day and Month to form Date
    
dt=driver.find_elements_by_xpath("//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']/div/div[1]/div/div[1]/h5") #Time
for i in dt:
    Date.append(i.text)

    
tim=driver.find_elements_by_xpath("//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']/div/div[1]/div/div[2]/h5") #Time
for i in tim:
    Time.append(i.text)
    
Fixtures=pd.DataFrame({}) #DataFrame
Fixtures['Match title'] = Match_title
Fixtures['Series'] = Series
Fixtures['Place'] = Place
Fixtures['Date'] = Date
Fixtures['Time'] = Time
Fixtures
# Out:
#                                 Match title  \
# 0  SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 1                 ICC WOMENS WORLD CUP 2022
# 2                 ICC WOMENS WORLD CUP 2022
# 3                 ICC WOMENS WORLD CUP 2022
# 4  SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 5                 ICC WOMENS WORLD CUP 2022
# 6                 ICC WOMENS WORLD CUP 2022
# 7                 ICC WOMENS WORLD CUP 2022
#
#                                      Series  \
# 0  SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 1                 ICC WOMENS WORLD CUP 2022
# 2                 ICC WOMENS WORLD CUP 2022
# 3                 ICC WOMENS WORLD CUP 2022
# 4  SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 5                 ICC WOMENS WORLD CUP 2022
# 6                 ICC WOMENS WORLD CUP 2022
# 7                 ICC WOMENS WORLD CUP 2022
#
#                                                Place         Date         Time
# 0  1st Test - Punjab Cricket Association IS Bindr...   4 MAR 2022  9:30 AM IST
# 1                          Bay Oval, Mount Maunganui   6 MAR 2022  6:30 AM IST
# 2                              Seddon Park, Hamilton  10 MAR 2022  6:30 AM IST
# 3                              Seddon Park, Hamilton  12 MAR 2022  6:30 AM IST
# 4        2nd Test - M Chinnaswamy Stadium, Bengaluru  12 MAR 2022  2:30 PM IST
# 5                          Bay Oval, Mount Maunganui  16 MAR 2022  6:30 AM IST
# 6                                Eden Park, Auckland  19 MAR 2022  6:30 AM IST
# 7                              Seddon Park, Hamilton  22 MAR 2022  6:30 AM IST

# %% [markdown]
# 3.Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through cod

# %%
url = 'https://www.guru99.com/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

text1 = driver.find_element_by_xpath("//div[@class='row featured-boxes']/div[1]/div/ul[1]/li[3]/a") #Looking for Selenium
#text2 = driver.find_elements_by_xpath("//li[@class='width:100%;']/a") #Looking for Hyperlink
#leng = len(text1)
#for i in range(0,leng):
#    if(text1[i].text == "Selenium"): #If selenium found open the link and break the loop
driver.get(text1.get_attribute('href'))
#driver.get(url)
time.sleep(4)

link1 = driver.find_elements_by_xpath("//table[@class='table'][5]/tbody/tr/td[2]") #Looking for Selenium Exception Handling
link2 = driver.find_elements_by_xpath("//table[@class='table'][5]/tbody/tr/td[1]/a") #Looking for Hyperlink
leng = len(link1)
for i in range(0,leng): #If found Exception Handling than open the link and break the loop
    if(link1[i].text == "Selenium Exception Handling (Common Exceptions List)"):
        url = link2[i].get_attribute('href')
        break
driver.get(url)
time.sleep(4)

Name = []
Desc = []
for i in range(2,43):
    link1 = driver.find_element_by_xpath("//table[@class='table table-striped']/tbody/tr["+str(i)+"]/td[1]") #Exception Name
    link2 = driver.find_element_by_xpath("//table[@class='table table-striped']/tbody/tr["+str(i)+"]/td[2]") #Description
    Name.append(link1.text)
    Desc.append(link2.text)
    
Exceptions=pd.DataFrame({}) #DataFrame
Exceptions['Exception name'] = Name
Exceptions['Description'] = Desc
Exceptions
# Out:
#                          Exception name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# 22            InvalidSessionIdException
# 23       InvalidSwitchToTargetException
# 24                  JavascriptException
# 25                        JsonException
# 26             NoSuchAttributeException
# 27       MoveTargetOutOfBoundsException
# 28               NoSuchContextException
# 29                NoSuchCookieException
# 30                    NotFoundException
# 31          RemoteDriverServerException
# 32                  ScreenshotException
# 33           SessionNotCreatedException
# 34           UnableToSetCookieException
# 35           UnexpectedTagNameException
# 36              UnhandledAlertException
# 37      UnexpectedAlertPresentException
# 38               UnknownMethodException
# 39          UnreachableBrowserException
# 40          UnsupportedCommandException
#
#                                           Description
# 0   This type of Selenium exception occurs when an...
# 1   This Selenium exception occurs when an element...
# 2   This Exception occurs if an element could not ...
# 3   This Exception occurs if the frame target to b...
# 4   This Exception occurs when you switch to no pr...
# 5   This Exception occurs if the window target to ...
# 6   This Selenium exception occurs happens when th...
# 7   The WebDriver is acting after you quit the bro...
# 8   Thrown when there is not enough time for a com...
# 9   This Exception takes place when the WebDriver ...
# 10  This type of Exception takes place when there ...
# 11  The command may not be completed as the elemen...
# 12  This Selenium exception is thrown when any ele...
# 13  This happens while interacting with the Firefo...
# 14  Exception is used as a placeholder in case if ...
# 15  This expectation will occur when IME engine ac...
# 16    It takes place when IME support is unavailable.
# 17  Navigation made the user agent to hit a certif...
# 18  It occurs when an argument does not belong to ...
# 19  This happens when you try to add a cookie unde...
# 20  This type of Exception matches an interacting ...
# 21  It occurs when command can’t be finished when ...
# 22  This Exception took place when the given sessi...
# 23  This occurs when the frame or window target to...
# 24  This issue occurs while executing JavaScript g...
# 25  It occurs when you afford to get the session w...
# 26  This kind of Exception occurs when the attribu...
# 27  It takes place if the target provided to the A...
# 28           ContextAware does mobile device testing.
# 29  This Exception occurs when no cookie matching ...
# 30  This Exception is a subclass of WebDriverExcep...
# 31  This Selenium exception is thrown when the ser...
# 32            It is not possible to capture a screen.
# 33  It happens when a new session could not be suc...
# 34  This occurs if a driver is unable to set a coo...
# 35  Happens if a support class did not get a web e...
# 36  This expectation occurs when there is an alert...
# 37  It occurs when there is the appearance of an u...
# 38  This Exception happens when the requested comm...
# 39  This Exception occurs only when the browser is...
# 40  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url = 'http://statisticstimes.com/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

India=driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[3]") #Looking for India
driver.get(India.get_attribute('href')) #Opening the hyperlink of India
time.sleep(2) #wait for 2 m.s.

State=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li[1]/a") #Looking for GDP of Indian States
driver.get(State.get_attribute('href')) #Opening the hyperlink of GDP of Indian States
time.sleep(2) #wait for 2 m.s.

Rank = []
State = []
GSDP19_20 = []
GSDP18_19 = []
Share_2018 = []
GDP_billion = []
for i in range(1,34): #33 States so running the loop for 1 to 34
    link1 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[1]") #Rank
    link2 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[2]") #State
    link3 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[3]") #GSDP19_20
    link4 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[4]") #GSDP18_19
    link5 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[5]") #Share_2018
    link6 = driver.find_element_by_xpath("//table[@id='table_id']/tbody/tr["+str(i)+"]/td[6]") #GDP_billion
    Rank.append(link1.text)
    State.append(link2.text)
    GSDP19_20.append(link3.text)
    GSDP18_19.append(link4.text)
    Share_2018.append(link5.text)
    GDP_billion.append(link6.text)
    
GSDP=pd.DataFrame({}) #DataFrame
GSDP['Rank'] = Rank
GSDP['State'] = State
GSDP['GSDP(19-20)'] = GSDP19_20
GSDP['SDP(18-19)'] = GSDP18_19
GSDP['Share(2018)'] = Share_2018
GSDP['GDP($ billion)'] = GDP_billion
GSDP
# Out:
#    Rank                      State GSDP(19-20) SDP(18-19) Share(2018)  \
# 0     1                Maharashtra           -  2,632,792      13.94%
# 1     2                 Tamil Nadu   1,845,853  1,630,208       8.63%
# 2     3              Uttar Pradesh   1,687,818  1,584,764       8.39%
# 3     4                    Gujarat           -  1,502,899       7.96%
# 4     5                  Karnataka   1,631,977  1,493,127       7.91%
# 5     6                West Bengal   1,253,832  1,089,898       5.77%
# 6     7                  Rajasthan   1,020,989    942,586       4.99%
# 7     8             Andhra Pradesh     972,782    862,957       4.57%
# 8     9                  Telangana     969,604    861,031       4.56%
# 9    10             Madhya Pradesh     906,672    809,592       4.29%
# 10   11                     Kerala           -    781,653       4.14%
# 11   12                      Delhi     856,112    774,870       4.10%
# 12   13                    Haryana     831,610    734,163       3.89%
# 13   14                      Bihar     611,804    530,363       2.81%
# 14   15                     Punjab     574,760    526,376       2.79%
# 15   16                     Odisha     521,275    487,805       2.58%
# 16   17                      Assam           -    315,881       1.67%
# 17   18               Chhattisgarh     329,180    304,063       1.61%
# 18   19                  Jharkhand     328,598    297,204       1.57%
# 19   20                Uttarakhand           -    245,895       1.30%
# 20   21            Jammu & Kashmir           -    155,956       0.83%
# 21   22           Himachal Pradesh     165,472    153,845       0.81%
# 22   23                        Goa      80,449     73,170       0.39%
# 23   24                    Tripura      55,984     49,845       0.26%
# 24   25                 Chandigarh           -     42,114       0.22%
# 25   26                 Puducherry      38,253     34,433       0.18%
# 26   27                  Meghalaya      36,572     33,481       0.18%
# 27   28                     Sikkim      32,496     28,723       0.15%
# 28   29                    Manipur      31,790     27,870       0.15%
# 29   30                   Nagaland           -     27,283       0.14%
# 30   31          Arunachal Pradesh           -     24,603       0.13%
# 31   32                    Mizoram      26,503     22,287       0.12%
# 32   33  Andaman & Nicobar Islands           -          -           -
#
#    GDP($ billion)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# 5         165.556
# 6         143.179
# 7         131.083
# 8         130.791
# 9         122.977
# 10        118.733
# 11        117.703
# 12        111.519
# 13         80.562
# 14         79.957
# 15         74.098
# 16         47.982
# 17         46.187
# 18         45.145
# 19         37.351
# 20         23.690
# 21         23.369
# 22         11.115
# 23          7.571
# 24          6.397
# 25          5.230
# 26          5.086
# 27          4.363
# 28          4.233
# 29          4.144
# 30          3.737
# 31          3.385
# 32              -

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
url = 'https://github.com/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

Trending=driver.find_element_by_xpath("//a[@href='/trending']") #Looking for Trending
driver.get(Trending.get_attribute('href')) #Open Trending page
time.sleep(2) #wait for 2 m.s.

Repository_title = []
Repository_description = []
Contributors_count = []
Language_used = []
for i in range(1,26): #25 repository are trending so running the loop for 1 to 26
    link1 = driver.find_element_by_xpath("//article[@class='Box-row']["+str(i)+"]/h1/a") #Repository Title
    Repository_title.append(link1.text)
    try:
        link2 = driver.find_element_by_xpath("//article[@class='Box-row']["+str(i)+"]/p") #Repository Description
        Repository_description.append(link2.text)
    except NoSuchElementException as e:
        Repository_description.append("-") #If Description is not present add "-"
    
urls = []
contr=driver.find_elements_by_xpath("//article[@class='Box-row']/h1/a") #Collecting the URLS of each repository
for i in contr:
    urls.append(i.get_attribute('href')) #Added url in urls field
    
for i in urls:
    driver.get(i) #Open the URL one by one
    time.sleep(2)
    counter = 0
    for i in range(1,6):
        try:
            test = driver.find_element_by_xpath("//div[@class='BorderGrid BorderGrid--spacious']/div["+str(i)+"]/div/h2/a") #Searching for Contributors
            value = test.text
            if(value.find("Contributors") != -1): #If found than
                con = value.split(" ")            #Split value with space
                Contributors_count.append(con[1]) #Second value will be number of Contributors
            else:
                counter += 1
        except NoSuchElementException as e:
            counter += 1
            pass
    if(counter == 5):
        Contributors_count.append("-")           #If no Contributors for that Repository than add "-"
        
    count = 0
    for i in range(1,7):
        try:
            test = driver.find_element_by_xpath("//div[@class='BorderGrid BorderGrid--spacious']/div["+str(i)+"]/div/h2") #Searching for Language Used
            value = test.text
            string = ""
            if(value.find("Languages") != -1): #If Language found than
                lang = driver.find_elements_by_xpath("//div[@class='BorderGrid BorderGrid--spacious']/div["+str(i)+"]/div/ul/li/a/span[1]")
                for i in lang:
                    string = string + i.text + " " #Added all languages one by one
                Language_used.append(string)
            else:
                count += 1
        except NoSuchElementException as e:
            count += 1
            pass
    if(count == 6):
        Language_used.append("-")                 #If no Language found then add "-"
        
Github = pd.DataFrame({}) #DataFrame
Github['Repository Title'] = Repository_title
Github['Repository Description'] = Repository_description
Github['Contributors Count'] = Contributors_count
Github['Language Used'] = Language_used
Github
# Out:
#                                     Repository Title  \
# 0                             Anduin2017 / HowToCook
# 1                                commaai / openpilot
# 2                             withfig / autocomplete
# 3                              doocs / advanced-java
# 4              BySergeyDev / NvidiaRTX-LHRv2Unlocker
# 5                     labuladong / fucking-algorithm
# 6                         J0hnbX / RedTeam-Resources
# 7                  danistefanovic / build-your-own-x
# 8                       vvmdx / Sec-Interview-4-2023
# 9               coding-horror / basic-computer-games
# 10                                   zadam / trilium
# 11                             automerge / automerge
# 12           danielbeach / data-engineering-practice
# 13                                 netdata / netdata
# 14                              NVlabs / instant-ngp
# 15                                     rui314 / mold
# 16                             iperov / DeepFaceLive
# 17                                tiangolo / fastapi
# 18  cat-milk / Anime-Girls-Holding-Programming-Books
# 19                           hasura / graphql-engine
# 20                       ant-design / pro-components
# 21                        aquasecurity / cloudsploit
# 22                                cube0x0 / BofRoast
# 23                                    cosmtrek / air
# 24             OpenZeppelin / openzeppelin-contracts
#
#                                Repository Description Contributors Count  \
# 0   程序员在家做饭方法指南。Programmer's guide about how to co...                116
# 1   openpilot is an open source driver assistance ...                280
# 2             Fig adds autocomplete to your terminal.                182
# 3   😮 Core Interview Questions & Answers For Exper...                  -
# 4   The first fully automated BIOS modifier for RT...                  -
# 5   刷算法全靠套路，认准 labuladong 就够了！English version supp...                 97
# 6                                                   -                  3
# 7           🤓 Build your own (insert technology here)                 72
# 8                一个2023届毕业生在毕业前持续更新、收集的安全岗面试题及面试经验分享~                  -
# 9   An updated version of the classic "Basic Compu...                156
# 10  Build your personal knowledge base with Triliu...                  -
# 11  A JSON-like data structure (a CRDT) that can b...                 57
# 12                 Data Engineering Practice Problems                  -
# 13  Real-time performance monitoring, done right! ...                496
# 14  Instant neural graphics primitives: lightning ...                 10
# 15                              mold: A Modern Linker                 34
# 16  Real-time face swap for PC streaming or video ...                  2
# 17  FastAPI framework, high performance, easy to l...                  -
# 18              Anime Girls Holding Programming Books                166
# 19  Blazing fast, instant realtime GraphQL APIs on...                415
# 20                       🏆 Use Ant Design like a Pro!                421
# 21           Cloud Security Posture Management (CSPM)                 63
# 22  Beacon Object Files for roasting Active Directory                  -
# 23                         ☁️ Live reload for Go apps                  -
# 24  OpenZeppelin Contracts is a library for secure...                307
#
#                                      Language Used
# 0                                                -
# 1                Python C++ C Cython MATLAB Shell
# 2                                      TypeScript
# 3                                                -
# 4                                                -
# 5                                        Markdown
# 6                                          Python
# 7                                                -
# 8                                                -
# 9            C# JavaScript Java Python Perl BASIC
# 10                                               -
# 11                          JavaScript TypeScript
# 12                              Python Dockerfile
# 13             C Python JavaScript Shell CSS HTML
# 14             Cuda C++ Python CMake C Dockerfile
# 15                                      C++ Shell
# 16                                         Python
# 17                                               -
# 18                                               -
# 19  Haskell TypeScript JavaScript Go Python Shell
# 20                     TypeScript Less JavaScript
# 21                                     JavaScript
# 22                              C Python Makefile
# 23                                               -
# 24                       JavaScript Solidity Ruby

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
url = 'https://www.billboard.com/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

Hot=driver.find_element_by_xpath("//li[@class='o-nav__list-item '][1]/a") #Getting the URL of HOT 100 songs
driver.get(Hot.get_attribute('href')) #Opening the URL
time.sleep(2) #wait for 2 m.s.

Song_name = []
Artist_name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []
link1 = driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[1]/h3") #Song_name
for i in link1:
    Song_name.append(i.text)
link2 = driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[1]/span") #Artist_name
for i in link2:
    Artist_name.append(i.text)
link3 = driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[4]") #Last week rank
for i in link3:
    Last_week_rank.append(i.text)
link4 = driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[5]") #Peak Rank
for i in link4:
    Peak_rank.append(i.text)
link5 = driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[6]") #Weeks on board
for i in link5:
    Weeks_on_board.append(i.text)
    
Songs = pd.DataFrame({}) #DataFrame
Songs['Song name'] = Song_name
Songs['Artist name'] = Artist_name
Songs['Last week rank'] = Last_week_rank
Songs['Peak rank'] = Peak_rank
Songs['Weeks on board'] = Weeks_on_board
Songs
# Out:
#                           Song name  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                        Easy On Me
# 3                           abcdefu
# 4                              Stay
# ..                              ...
# 95  All Too Well (Taylor's Version)
# 96       Come Back As A Country Boy
# 97                             Iffy
# 98                       Home Sweet
# 99                         Too Easy
#
#                                           Artist name Last week rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                                       Glass Animals              4
# 2                                               Adele              3
# 3                                               GAYLE              7
# 4                       The Kid LAROI & Justin Bieber              5
# ..                                                ...            ...
# 95                                       Taylor Swift             84
# 96                                      Blake Shelton             89
# 97                                        Chris Brown             96
# 98                                  Russell Dickerson             94
# 99                                     Gunna & Future             92
#
#    Peak rank Weeks on board
# 0          1              8
# 1          2             57
# 2          1             19
# 3          4             13
# 4          1             32
# ..       ...            ...
# 95         1             14
# 96        85              5
# 97        71              5
# 98        88              5
# 99        16             16
#
# [100 rows x 5 columns]

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through cod

# %%
url = 'https://www.naukri.com/naukri-dot-com-recruiters' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

#time.sleep(2) #wait for 2 m.s.

search_job = driver.find_element_by_xpath("//input[@class='sugInp']") #search bar
search_job.send_keys("Data science") #Adding "Data science" in search bar

search_btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']") #submit button
search_btn.click() #submitting the input
time.sleep(2) #wait for 2 m.s.

Name = []
Designation = []
Company = []
Skills_they_hire_for = []
Location = []
for i in range(1,26): # 50 Recruiter are there in pair of 2 so we'll run the loop from 1 to 26
    link1 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[1]/div/div/p/a[1]/span") #Name
    Name.append(link1.text)
    link2 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[2]/div/div/p/a[1]/span") #Name
    Name.append(link2.text)
    link1 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[1]/div/div/p/span[1]") #Designation
    Designation.append(link1.text)
    link2 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[2]/div/div/p/span[1]") #Designation
    Designation.append(link2.text)
    link1 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[1]/div/div/p/a[2]") #Company
    Company.append(link1.text)
    link2 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[2]/div/div/p/a[2]") #Company
    Company.append(link2.text)
    try:
        link1 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[1]/div/div/p/span[2]/small") #Location
        Location.append(link1.text)
    except NoSuchElementException as e:
        Location.append("-") #If not found add "-"
    try:
        link2 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[2]/div/div/p/span[2]/small") #Location
        Location.append(link2.text)
    except NoSuchElementException as e:
        Location.append("-") #If not found add "-"
    link1 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[1]/div/div[2]") #Skills
    Skills_they_hire_for.append(link1.text)
    link2 = driver.find_element_by_xpath("//div[@class='outerRecSec']["+str(i)+"]/div[2]/div/div[2]") #Skills
    Skills_they_hire_for.append(link2.text)
    
Naukri = pd.DataFrame({}) #DataFrame
Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Skills they hire for'] = Skills_they_hire_for
Naukri['Location'] = Location
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                  Priyanka Akiri
# 8                                 Kalpana Dumpala
# 9                                     Balu Ramesh
# 10                                        Mubarak
# 11                                 Kushal Rastogi
# 12                             Mahesh Babu Channa
# 13                                Sakshi Chhikara
# 14                                   Kapil Devang
# 15                                    Ruchi Dhote
# 16                             Sandhya Khandagale
# 17                                  Manisha Yadav
# 18                                    Riya Rajesh
# 19                           Rashmi Bhattacharjee
# 20                                  Manjunathan D
# 21                                  Faizan Kareem
# 22                                 Rithika dadwal
# 23                                      Shaun Rao
# 24                                  Azahar Shaikh
# 25                                  Asif Lucknowi
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                    Priya Khare
# 34                                    Amit Sharma
# 35                                          Kanan
# 36                           Shashikant Chaudhary
# 37                                           Brad
# 38                                   Rutuja Pawar
# 39                            Madhusudhan Sridhar
# 40                                    Ankit Sinha
# 41                                 Gaurav Chouhan
# 42                                   Rashi Kacker
# 43                                        Ashwini
# 44                                   Balaji Kolli
# 45                                 Rajani Nagaraj
# 46                                    ROHIT Kumar
# 47                                 Amir Chowdhury
# 48                              Radha Manivasagam
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                            HR Manager
# 8                      Executive Hiring
# 9                      HR Administrator
# 10                           Company HR
# 11                           Company HR
# 12                         HR Team Lead
# 13                 Assistant Manager HR
# 14                           HR Manager
# 15  Senior Executive Talent Acquisition
# 16                         HR Recruiter
# 17                         HR Executive
# 18           Manager Talent Acquisition
# 19                              HR Head
# 20                         IT Recruiter
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23              Manager Human Resources
# 24                    Company Recruiter
# 25                             Director
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                       Senior Manager
# 34                           Consultant
# 35         senior technology instructor
# 36             HR Recruiter/HR Excutive
# 37        Manager, Technical Recruiting
# 38                  Technical Recruiter
# 39                      Erp Implementer
# 40                       Head Analytics
# 41              Chief Technical Officer
# 42                   Sr Product Manager
# 43             Director Global Delivery
# 44                           Co Founder
# 45                           HR Manager
# 46                            Architect
# 47                     Managing Partner
# 48                         HR Executive
# 49               Recruitment Consultant
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                    Infinitive Software Solutions
# 8                               Innominds Software
# 9                      Techvantage Systems Pvt Ltd
# 10                                        MoneyTap
# 11              QuantMagnum Technologies Pvt. Ltd.
# 12                               SocialPrachar.com
# 13                   BIZ INFOTECNO PRIVATE LIMITED
# 14                                  BISP Solutions
# 15                           Bristlecone India Ltd
# 16                 Compumatrice Multimedia Pvt Ltd
# 17                                        Easi Tax
# 18                     Novelworx Digital Solutions
# 19         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 20                  SFJ Business Solutions Pvt Ltd
# 21                   FirstTech Consaltants Pvt.Ltd
# 22                                Affine Analytics
# 23                              Exela Technologies
# 24                 NEAL ANALYTICS SERVICES PVT LTD
# 25                      Weupskill- Live Wire India
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31                              Nikitha Palaparthi
# 32        Dollarbird Information Services Pvt, Ltd
# 33                          Independent Consultant
# 34                                 ASCO consulting
# 35                                         NY INST
# 36  3D India Staffing Research &amp; Consulting...
# 37                                     O.C. Tanner
# 38                                   Demand Matrix
# 39                             MADHUSUDHAN SRIDHAR
# 40                                  Suntech Global
# 41                        Strategic Consulting Lab
# 42                            Impel Labs Pvt. Ltd.
# 43                                    MRP Advisers
# 44                   Saras Solutions India Pvt Ltd
# 45                                     WildJasmine
# 46                             LNT Private Limited
# 47                                     Granular.ai
# 48                                      Techcovery
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                  Skills they hire for  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Oracle Dba, Data Science, Data Warehousing, ET...
# 8   Qa, Ui/ux, Java Developer, Java Architect, C++...
# 9   Machine Learning, algorithms, Go Getter, Compu...
# 10  Business Intelligence, Data Warehousing, Data ...
# 11  Office Administration, Hr Administration, tele...
# 12  Social Media, digital media maketing, seo, smm...
# 13  React.js, Data Science, Java, Front End, Busin...
# 14     Big Data, Hadoop, Data Analytics, Data Science
# 15  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 16  Big Data, Data Science, Artificial Intelligenc...
# 17  Telecalling, Client Interaction, Marketing, Re...
# 18                                       Data Science
# 19  Corporate Sales, Software Development, Softwar...
# 20  Java, C#, Aws, Cloud, Odi, Automation, Seleniu...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 24  Data Science, Artificial Intelligence, Machine...
# 25  Technical Training, Software Development, Pres...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  Python, Artificial Intelligence, Machine Learn...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                  Hyderabad
# 8   Hyderabad / Secunderabad
# 9                 Trivandrum
# 10     Bengaluru / Bangalore
# 11                    Mumbai
# 12  Hyderabad / Secunderabad
# 13                Chandigarh
# 14                    Bhopal
# 15                      Pune
# 16                      Pune
# 17               Navi Mumbai
# 18                    Cochin
# 19                     Delhi
# 20     Bengaluru / Bangalore
# 21  Hyderabad / Secunderabad
# 22                      Pune
# 23                      Pune
# 24                      Pune
# 25                    Indore
# 26     Bengaluru / Bangalore
# 27     Bengaluru / Bangalore
# 28                         -
# 29                     Delhi
# 30     Bengaluru / Bangalore
# 31  Hyderabad / Secunderabad
# 32           Mysoru / Mysore
# 33     Bengaluru / Bangalore
# 34                 New Delhi
# 35                   Chennai
# 36                   Aligarh
# 37            Salt Lake City
# 38                      Pune
# 39     Bengaluru / Bangalore
# 40                    Mumbai
# 41                    Indore
# 42     Bengaluru / Bangalore
# 43                    MYSORE
# 44  Hyderabad / Secunderabad
# 45     Bengaluru / Bangalore
# 46                    Mumbai
# 47                         -
# 48     Bengaluru / Bangalore
# 49  Hyderabad / Secunderabad

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []
for i in range(1,101): #100 books are available, So we'll run the loop from 1 to 101
    link1 = driver.find_element_by_xpath("//tbody/tr["+str(i)+"]/td[2]") #Book_name
    Book_name.append(link1.text)
    link2 = driver.find_element_by_xpath("//tbody/tr["+str(i)+"]/td[3]") #Author_name
    Author_name.append(link2.text)
    link3 = driver.find_element_by_xpath("//tbody/tr["+str(i)+"]/td[4]") #Volumes_sold
    Volumes_sold.append(link3.text)
    link4 = driver.find_element_by_xpath("//tbody/tr["+str(i)+"]/td[5]") #Publisher
    Publisher.append(link4.text)
    link5 = driver.find_element_by_xpath("//tbody/tr["+str(i)+"]/td[6]") #Genre
    Genre.append(link5.text)
    
Book = pd.DataFrame({}) #DataFrame
Book['Book name'] = Book_name
Book['Author name'] = Author_name
Book['Volumes sold'] = Volumes_sold
Book['Publisher'] = Publisher
Book['Genre'] = Genre
Book
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url = 'https://www.imdb.com/list/ls095964455/' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []
for i in range(1,101): #100 shows are available, running the loop from 1 to 101
    link1 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/h3/a") #Name
    Name.append(link1.text)
    link2 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/h3/span[2]") #Year_span
    Year_span.append(link2.text)
    link3 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/p[1]/span[5]") #Genre
    Genre.append(link3.text)
    link4 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/p[1]/span[3]") #Run_time
    Run_time.append(link4.text)
    link5 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/div[1]/div/span[2]") #Ratings
    Ratings.append(link5.text)
    link6 = driver.find_element_by_xpath("//div[@class='lister-item mode-detail']["+str(i)+"]/div[2]/p[4]/span[2]") #Votes
    Votes.append(link6.text)
    
Shows = pd.DataFrame({}) #DataFame
Shows['Name'] = Name
Shows['Year span'] = Year_span
Shows['Genre'] = Genre
Shows['Run time'] = Run_time
Shows['Ratings'] = Ratings
Shows['Votes'] = Votes
Shows
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  1,955,735
# 1    51 min     8.7    965,630
# 2    44 min     8.1    931,533
# 3    60 min     7.5    278,932
# 4    43 min     7.6    239,114
# ..      ...     ...        ...
# 95   42 min     7.5     47,774
# 96   50 min     7.8     58,499
# 97   42 min     8.1    185,596
# 98   45 min     7.1     39,282
# 99  572 min     8.6    221,876
#
# [100 rows x 6 columns]

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
url = 'https://archive.ics.uci.edu/ml/index.php' #getting the required url
driver.get(url)

time.sleep(2) #wait for 2 m.s.

Data=driver.find_element_by_xpath("//td[2]/span[2]/a")
driver.get(Data.get_attribute('href'))
time.sleep(2) #wait for 2 m.s.

Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attribute = []
Year = []
for i in range(2,560): #There are almost 558 records are present, running the loop from 2 to 560, row 1 is header, we don't want it.
    link1 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[1]/table/tbody/tr/td[2]/p/b/a") #Dataset_name
    Dataset_name.append(link1.text)
    link2 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[2]/p") #Data_type
    Data_type.append(link2.text)
    link3 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[3]/p") #Task
    Task.append(link3.text)
    link4 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[4]/p") #Attribute_type
    Attribute_type.append(link4.text)
    link5 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[5]/p") #No_of_instances
    No_of_instances.append(link5.text)
    link6 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[6]/p") #No_of_attribute
    No_of_attribute.append(link6.text)
    link7 = driver.find_element_by_xpath("//table/tbody/tr/td[2]/table[2]/tbody/tr["+str(i)+"]/td[7]/p") #Year
    Year.append(link7.text)
    
Dataset = pd.DataFrame({}) #DataFrame
Dataset['Dataset name'] = Dataset_name
Dataset['Data type'] = Data_type
Dataset['Task'] = Task
Dataset['Attribute type'] = Attribute_type
Dataset['No of instances'] = No_of_instances
Dataset['No of attribute'] = No_of_attribute
Dataset['Year'] = Year
Dataset
# Out:
#                                   Dataset name      Data type  \
# 0                                      Abalone  Multivariate
# 1                                        Adult  Multivariate
# 2                                    Annealing  Multivariate
# 3                 Anonymous Microsoft Web Data
# 4                                   Arrhythmia  Multivariate
# ..                                         ...            ...
# 553               South German Credit (UPDATE)  Multivariate
# 554  IIWA14-R820-Gazebo-Dataset-10Trajectories
# 555             Guitar Chords finger positions          Text
# 556       Russian Corpus of Biographical Texts          Text
# 557                                Codon usage  Multivariate
#
#                                         Task               Attribute type  \
# 0                            Classification   Categorical, Integer, Real
# 1                            Classification         Categorical, Integer
# 2                            Classification   Categorical, Integer, Real
# 3                       Recommender-Systems                  Categorical
# 4                            Classification   Categorical, Integer, Real
# ..                                       ...                          ...
# 553  Classification, Regression, Clustering                Integer, Real
# 554                              Regression                      Integer
# 555                          Classification
# 556                          Classification
# 557              Classification, Clustering
#
#     No of instances No of attribute   Year
# 0             4177               8   1995
# 1            48842              14   1996
# 2              798              38
# 3            37711             294   1998
# 4              452             279   1998
# ..              ...             ...    ...
# 553           1000              21   2020
# 554                                  2020
# 555           2633               5   2020
# 556            200               2   2020
# 557          13028              69   2020
#
# [558 rows x 7 columns]
